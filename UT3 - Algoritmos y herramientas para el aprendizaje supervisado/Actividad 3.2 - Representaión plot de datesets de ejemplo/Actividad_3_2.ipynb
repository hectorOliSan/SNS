# %% [markdown]
# # Librería - **Seaborn**

# %%
import seaborn as sns

# %% [markdown]
# Para la **representación**:
# - **hue** o matiz : (opcional) este parámetro toma el nombre de columna para la codificación de color.

# %% [markdown]
# ### Dataset - 🌍 **Planets**

# %%
df_planets = sns.load_dataset("planets")
df_planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %% [markdown]
# **Representación:**

# %%
sns.pairplot(df_planets, hue="method")

# %% [markdown]
# **Conclusión:** Observamos que en esta gráfica el conjunto de datos  no tienen correlación las observaciones de las variables entre sí.

# %% [markdown]
# ---

# %% [markdown]
# ### Dataset - ✈️ **Flights**

# %%
df_flights = sns.load_dataset("flights")
df_flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# **Representación:**

# %%
sns.pairplot(df_flights, hue="month")

# %% [markdown]
# **Conclusión:** Todo lo contrario a la gráfica anterior, támbien es un dataset más pequeño, se observa que hay relación entre los años y los pasajeros, a través de los meses.

# %% [markdown]
# ---

# %% [markdown]
# ### Dataset - 🐧 **Penguins**

# %%
df_penguins = sns.load_dataset("penguins")
df_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **Representación:**

# %%
sns.pairplot(df_penguins, hue="species")

# %% [markdown]
# **Conclusión**: Me parece la gráfica más "entendible" de las tres, ya que se parece a la de las flores iris, y se observa que hay bastante relación entre algunas variables  conjunto de datos, como el body_mass_g con bill_length_mm o el flipper_length_mm con body_mass_g.
